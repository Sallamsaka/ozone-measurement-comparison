# %%
import numpy as np
import xarray as xr
import dask.array as da
from dask.distributed import Client, LocalCluster
import gc
import sys
from matplotlib import pyplot as plt

# %%
EARTH_RADIUS_KM = 6371.0
MAX_DIST_KM = 500
TIME_TOL_HOURS = 8
ALT_MIN, ALT_MAX = 8.5, 57.5
ALT_GRID = np.arange(ALT_MIN, ALT_MAX + 1, dtype=np.float32)
TIME_TOL = np.timedelta64(TIME_TOL_HOURS, 'h').astype('timedelta64[ns]')

CHUNK_SIZE_L = 100000
CHUNK_SIZE_S = 50000

# %%
def process_dataarray(da_o3):
    if not "DATETIME" in da_o3.coords:
        time_chunks = CHUNK_SIZE_L if da_o3.size > 500000 else CHUNK_SIZE_S
        
        if isinstance(da_o3.data, da.Array):
            da_o3 = da_o3.chunk({'time': time_chunks})
        else:
            da_o3.data = da.from_array(da_o3.data, 
                                            chunks= time_chunks)
    
    else:
        time_chunks = CHUNK_SIZE_L if da_o3.size > 500000 else CHUNK_SIZE_S
        
        if isinstance(da_o3.data, da.Array):
            da_o3 = da_o3.chunk({'DATETIME': time_chunks})
        else:
            da_o3.data = da.from_array(da_o3.data, 
                                            chunks= time_chunks)
    return da_o3

def compute_diffs(o3L, o3S):
    """Vectorized relative, absolute and raw difference computation"""
    sum_vals = o3L + o3S
    diff_vals = o3L - o3S
    return 200 * (diff_vals / sum_vals), np.abs(diff_vals), diff_vals

def haversine_vectorized(lat1, lon1, lat2, lon2):
    """Vectorized Haversine distance calculation between points (in radians)"""
    lat1 = np.deg2rad(lat1)
    lon1 = np.deg2rad(lon1)
    lat2 = np.deg2rad(lat2)
    lon2 = np.deg2rad(lon2)
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    return EARTH_RADIUS_KM * c

# %%
import ACEFTS.ACEFTS_helper as ACE
import PEARL_FTIR.PEARL_FTIR_helper as PEARL

# %%
daA = ACE.get_column_DU(ALT_MIN, ALT_MAX)
daP = PEARL.get_column_DU(ALT_MIN, ALT_MAX)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 daA = ACE.get_column_DU(ALT_MIN, ALT_MAX)
#       2 daP = PEARL.get_column_DU(ALT_MIN, ALT_MAX)
#
# File ~\OneDrive - University of Toronto\Desktop\School Information\NSERC\NSERC\O3_ANALYSIS\ACEFTS\ACEFTS_helper.py:86, in get_column_DU(min_alt, max_alt)
#      85 def get_column_DU(min_alt = f.altitude.min(), max_alt = f.altitude.max()):
# ---> 86     column = get_column(min_alt, max_alt)
#      87     return column / 2.687e20
#
# File ~\OneDrive - University of Toronto\Desktop\School Information\NSERC\NSERC\O3_ANALYSIS\ACEFTS\ACEFTS_helper.py:81, in get_column(min_alt, max_alt)
#      80 def get_column(min_alt = f.altitude.min(), max_alt = f.altitude.max()):
# ---> 81     O3_density = get_density()
#      82     return (O3_density * 1000).sel(altitude = slice(min_alt, max_alt)).sum(dim = "altitude") * 6.022e23
#
# File ~\OneDrive - University of Toronto\Desktop\School Information\NSERC\NSERC\O3_ANALYSIS\ACEFTS\ACEFTS_helper.py:77, in get_density()
#      76 def get_density():
# ---> 77     return O3_vmr * (get_pressure()/(8.3145 * get_temperature()))
#
# File ~\OneDrive - University of Toronto\Desktop\School Information\NSERC\NSERC\O3_ANALYSIS\ACEFTS\ACEFTS_helper.py:95, in get_pressure()
#      94 def get_pressure():
# ---> 95     return f["pressure"][:].T.where(flags_sorted == 0)
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\_typed_ops.py:720, in DataArrayOpsMixin.__eq__(self, other)
#     719 def __eq__(self, other: DaCompatible) -> Self | Dataset | DataTree:
# --> 720     return self._binary_op(other, nputils.array_eq)
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\dataarray.py:4849, in DataArray._binary_op(self, other, f, reflexive)
#    4845 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
#    4846 other_coords = getattr(other, "coords", None)
#    4848 variable = (
# -> 4849     f(self.variable, other_variable_or_arraylike)
#    4850     if not reflexive
#    4851     else f(other_variable_or_arraylike, self.variable)
#    4852 )
#    4853 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4854 name = result_name([self, other])
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\nputils.py:114, in array_eq(self, other)
#     112 with warnings.catch_warnings():
#     113     warnings.filterwarnings("ignore", r"elementwise comparison failed")
# --> 114     return _ensure_bool_is_ndarray(self == other, self, other)
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\_typed_ops.py:1145, in VariableOpsMixin.__eq__(self, other)
#    1144 def __eq__(self, other: VarCompatible) -> Self | T_DA | Dataset | DataTree:
# -> 1145     return self._binary_op(other, nputils.array_eq)
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\variable.py:2334, in Variable._binary_op(self, other, f, reflexive)
#    2332     other_data, self_data, dims = _broadcast_compat_data(other, self)
#    2333 else:
# -> 2334     self_data, other_data, dims = _broadcast_compat_data(self, other)
#    2335 keep_attrs = _get_keep_attrs(default=False)
#    2336 attrs = self._attrs if keep_attrs else None
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\variable.py:2945, in _broadcast_compat_data(self, other)
#    2942     dims = new_self.dims
#    2943 else:
#    2944     # rely on numpy broadcasting rules
# -> 2945     self_data = self.data
#    2946     other_data = other
#    2947     dims = self.dims
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\variable.py:416, in Variable.data(self)
#     414     duck_array = self._data.array
#     415 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 416     duck_array = self._data.get_duck_array()
#     417 elif is_duck_array(self._data):
#     418     duck_array = self._data
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\indexing.py:730, in LazilyVectorizedIndexedArray.get_duck_array(self)
#     726     array = apply_indexer(self.array, self.key)
#     727 else:
#     728     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     729     # it may wrap a BackendArray so use its __getitem__
# --> 730     array = self.array[self.key]
#     731 # self.array[self.key] is now a numpy array when
#     732 # self.array is a BackendArray subclass
#     733 # and self.key is BasicIndexer((slice(None, None, None),))
#     734 # so we need the explicit check for ExplicitlyIndexed
#     735 if isinstance(array, ExplicitlyIndexed):
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\backends\netCDF4_.py:103, in NetCDF4ArrayWrapper.__getitem__(self, key)
#     102 def __getitem__(self, key):
# --> 103     return indexing.explicit_indexing_adapter(
#     104         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     105     )
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\indexing.py:1014, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     987 def explicit_indexing_adapter(
#     988     key: ExplicitIndexer,
#     989     shape: _Shape,
#     990     indexing_support: IndexingSupport,
#     991     raw_indexing_method: Callable[..., Any],
#     992 ) -> Any:
#     993     """Support explicit indexing by delegating to a raw indexing method.
#     994
#     995     Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1012     Indexing result, in the form of a duck numpy-array.
#    1013     """
# -> 1014     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
#    1015     result = raw_indexing_method(raw_key.tuple)
#    1016     if numpy_indices.tuple:
#    1017         # index the loaded duck array
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\indexing.py:1047, in decompose_indexer(indexer, shape, indexing_support)
#    1043 def decompose_indexer(
#    1044     indexer: ExplicitIndexer, shape: _Shape, indexing_support: IndexingSupport
#    1045 ) -> tuple[ExplicitIndexer, ExplicitIndexer]:
#    1046     if isinstance(indexer, VectorizedIndexer):
# -> 1047         return _decompose_vectorized_indexer(indexer, shape, indexing_support)
#    1048     if isinstance(indexer, BasicIndexer | OuterIndexer):
#    1049         return _decompose_outer_indexer(indexer, shape, indexing_support)
#
# File c:\Users\salla\anaconda3\Lib\site-packages\xarray\core\indexing.py:1144, in _decompose_vectorized_indexer(indexer, shape, indexing_support)
#    1140     np_indexer_elems.append(np_slice)
#    1141 else:
#    1142     # If it is a (multidimensional) np.ndarray, just pickup the used
#    1143     # keys without duplication and store them as a 1d-np.ndarray.
# -> 1144     oind, vind = np.unique(k, return_inverse=True)
#    1145     backend_indexer_elems.append(oind)
#    1146     np_indexer_elems.append(vind.reshape(*k.shape))
#
# File c:\Users\salla\anaconda3\Lib\site-packages\numpy\lib\_arraysetops_impl.py:291, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     289 ar = np.asanyarray(ar)
#     290 if axis is None:
# --> 291     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     292                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None)
#     293     return _unpack_tuple(ret)
#     295 # axis was specified and not None
#
# File c:\Users\salla\anaconda3\Lib\site-packages\numpy\lib\_arraysetops_impl.py:380, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis)
#     378     ret += (perm[mask],)
#     379 if return_inverse:
# --> 380     imask = np.cumsum(mask) - 1
#     381     inv_idx = np.empty(mask.shape, dtype=np.intp)
#     382     inv_idx[perm] = imask
#
# File c:\Users\salla\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:2980, in cumsum(a, axis, dtype, out)
#    2904 @array_function_dispatch(_cumsum_dispatcher)
#    2905 def cumsum(a, axis=None, dtype=None, out=None):
#    2906     """
#    2907     Return the cumulative sum of the elements along a given axis.
#    2908
#    (...)
#    2978
#    2979     """
# -> 2980     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#
# File c:\Users\salla\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# MemoryError: Unable to allocate 151. MiB for an array with shape (19810650,) and data type int64

# %%
daA = process_dataarray(daA)
daP = process_dataarray(daP)

# %%
cluster = LocalCluster(
    n_workers=2,
    threads_per_worker=2,
    memory_limit='3GB',
    processes=False,
    dashboard_address=None
)
client = Client(cluster)

# %%
o3A_arr = daA.values.astype(np.float32)
latA = daA.latitude.values
lonA = daA.longitude.values
tA = daA.time.values.astype('datetime64[ns]')

o3P_arr = daP.values.astype(np.float32)
tP = daP.DATETIME.values.astype('datetime64[ns]')
num_P_data = len(tP)
latP = np.array([PEARL.latitude] * num_P_data)
lonP = np.array([PEARL.longitude] * num_P_data)

tP_min = tP.min() - TIME_TOL
tP_max = tP.max() + TIME_TOL
first_time_mask = (tA >= tP_min) & (tA <= tP_max)
tA_filtered = tA[first_time_mask]
o3A_arr_filtered = o3A_arr[first_time_mask]
latA_filtered = latA[first_time_mask]
lonA_filtered = lonA[first_time_mask]

client.close()
cluster.close()
del o3A_arr, latA, lonA
gc.collect()
# Out:
# 8571

# %%
tA_ns = tA_filtered.astype(np.int64)
tP_ns = tP.astype(np.int64)
TIME_TOL_ns = TIME_TOL.astype(np.int64)

MAX_DIST_RAD = MAX_DIST_KM / EARTH_RADIUS_KM

processed_pairs = 0
o3P_coincidences = []
o3A_coincidences = []
o3P_coincidences_idx = []
o3A_coincidences_idx = []
days_of_year = []

time_bins = np.arange(tA_ns.min(), tA_ns.max() + 1, TIME_TOL_ns)
bin_indices = np.digitize(tA_ns, time_bins)

max_bin = len(time_bins) + 1
time_binned_arrays = [np.array([], dtype=np.int64) for _ in range(max_bin + 1)]

for bin_id in range(0, max_bin + 1):
    time_binned_arrays[bin_id] = np.where(bin_indices == bin_id)[0]

bin_offsets = np.arange(-1, 2)

for s_idx, (s_time, s_lat, s_lon) in enumerate(zip(tP_ns, latP, lonP)):
    if s_idx % 10000 == 0:
        print(f"Processing PEARL FTIR point {s_idx}/{len(tP)}...")
    
    center_bin = np.digitize(s_time, time_bins)
    bin_ids = center_bin + bin_offsets
    bin_ids = bin_ids[(bin_ids >= 1) & (bin_ids < max_bin)]

    candidate_indices = np.concatenate([time_binned_arrays[bin_id] for bin_id in bin_ids])
    if candidate_indices.size == 0:
        continue

    time_diffs = np.abs(tA_ns[candidate_indices] - s_time)
    time_mask = time_diffs <= TIME_TOL_ns

    if not np.any(time_mask):
        continue

    time_valid_indices = candidate_indices[time_mask]
    candidate_lats = latA_filtered[time_valid_indices]
    candidate_lons = lonA_filtered[time_valid_indices]
    
    dists = haversine_vectorized(s_lat, s_lon, candidate_lats, candidate_lons)
    min_idx = np.argmin(dists)
    min_dist = dists[min_idx]

    if min_dist <= MAX_DIST_KM:
        best_L_idx = time_valid_indices[min_idx]
        o3A_coincidences.append(o3A_arr_filtered[best_L_idx])
        o3P_coincidences.append(o3P_arr[s_idx])
        processed_pairs += 1

        o3A_coincidences_idx.append(best_L_idx)
        o3P_coincidences_idx.append(s_idx)

        dt = tA_ns[best_L_idx]
        dt = dt.astype('datetime64[ns]')
        day_of_year = ((dt - dt.astype('datetime64[Y]'))   // np.timedelta64(1, 'D')) + 1

        days_of_year.append(day_of_year)
        if processed_pairs % 1000 == 0:
            print(f"Found {processed_pairs} pairs at PEARL FTIR point {s_idx}...")

o3P_coincidences = np.vstack(o3P_coincidences)
o3A_coincidences = np.vstack(o3A_coincidences)
print(f"Total coincidences found: {processed_pairs}")
# Out:
# Processing PEARL FTIR point 0/6261...
# Found 1000 pairs at PEARL FTIR point 4183...
# Total coincidences found: 1359

# %%
# o3S_coincidences[o3S_coincidences == 0] = np.nan
# o3L_coincidences[o3L_coincidences == 0] = np.nan
o3A_coincidences[o3A_coincidences == np.float32("inf")] = np.nan
o3P_coincidences[o3P_coincidences == np.float32("inf")] = np.nan

# %%
rel, abs, raw = compute_diffs(o3A_coincidences, o3P_coincidences)

# %%
plt.scatter(days_of_year, raw)
raw_mean = np.nanmean(raw)
xlims = list(plt.xlim())
plt.plot(xlims, [0, 0], color = "black")
plt.plot(xlims, [raw_mean, raw_mean], color = "red", linestyle = "dashed", label = "Mean Difference")
plt.xlabel("Day of Year")
plt.ylabel("Ozone Column (DU)")

plt.title("Absolute Differences between ACE-FTS and PEARL FTIR Partial Columns" + f" ({int(ALT_MIN - 0.5)}-{int(ALT_MAX + 0.5)}km)" + " (All Time)", fontdict = {'fontsize': 15}, pad=15)

plt.legend()
fig = plt.gcf()
axes = plt.gca()

title = axes.get_title()
fig.savefig(title, bbox_inches="tight")

# %%
plt.scatter(days_of_year, rel)
rel_mean = np.nanmean(rel)
xlims = list(plt.xlim())
plt.plot(xlims, [0, 0], color = "black")
plt.plot(xlims, [rel_mean, rel_mean], color = "red", linestyle = "dashed", label = "Mean Difference")
plt.xlabel("Day of Year")
plt.ylabel("Relative Difference (%)")

plt.title("Relative Differences between ACE-FTS and PEARL FTIR Partial Columns" + f" ({int(ALT_MIN - 0.5)}-{int(ALT_MAX + 0.5)}km)" + " (All Time)", fontdict = {'fontsize': 15}, pad=15)

plt.legend()
fig = plt.gcf()
axes = plt.gca()

title = axes.get_title()
fig.savefig(title, bbox_inches="tight")

# %%
plt.scatter(o3P_coincidences, o3A_coincidences, color = "blue")
plt.xlabel("PEARL FTIR Column (DU)")
plt.ylabel("ACE-FTS Column (DU)")

plt.title("PEARL FTIR vs ACE-FTS Partial Column Measurements" + f" ({int(ALT_MIN - 0.5)}-{int(ALT_MAX + 0.5)}km)" + " (All Time)", fontdict = {'fontsize': 15}, pad=15)
xlims = plt.xlim()
ylims = plt.ylim()
plt.plot([0, xlims[1]], [0, ylims[1]], color = "black", label = "Diagonal Line")

mask = np.isfinite(o3A_coincidences) & np.isfinite(o3P_coincidences)
o3L_coincidences_nonan = o3A_coincidences[mask]
o3S_coincidences_nonan = o3P_coincidences[mask]

slope, intercept = np.polyfit(o3S_coincidences_nonan, o3L_coincidences_nonan, 1)
line = slope * o3P_coincidences + intercept
plt.plot(o3P_coincidences, line, color = "red", label = "Line of Best Fit")
plt.xlim(100, 600)
plt.ylim(100, 600)

plt.legend()

fig = plt.gcf()
axes = plt.gca()

title = axes.get_title()
fig.savefig(title, bbox_inches="tight")

# %%
o3A_std = np.nanstd(o3A_coincidences)
o3P_std = np.nanstd(o3P_coincidences)
o3A_mean = np.nanmean(o3A_coincidences)
o3P_mean = np.nanmean(o3P_coincidences)

# %%
L_minus_mean = (o3A_coincidences - o3A_mean)
S_minus_mean = (o3P_coincidences - o3P_mean)

# %%
o3P_mean
# Out:
# np.float32(414.5732)

# %%
summing = np.nansum((L_minus_mean / o3A_std) * (S_minus_mean / o3P_std)) / (len(L_minus_mean) - 1)
summing
# Out:
# np.float32(0.8885813)
